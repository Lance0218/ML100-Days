# %% [markdown]
# # 作業1：
#
# ## 選取資料為：UCI ML Drug Review dataset (https://www.kaggle.com/jessicali9530/kuc-hackathon-winter-2018)
#
# ### Q1. 你選的這組資料為何重要：
# ### A1. 該數據集提供了個別藥物的患者評論伴隨著相關條件，以及反映患者總體滿意度的10星級患者評級，可作為藥物分析之用，同時也是 Winter 2018 Kaggle University Club Hackathon 的指定資料。
#
# ### Q2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)：
# ### A2. 透過爬網在線藥物評論網站獲得。
#
# ### Q3. 蒐集而來的資料型態為何：
# ### A3. 結構化之表格。
#
# ### Q4. 這組資料想解決的問題如何評估：
# ### A4. 本資料想評估藥物多方面的文本情感分析(如有效性和副作用之文本情感分析)，應使用迴歸分析。

# %% [markdown]
# # 作業2：
#
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ### Q1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# ### A1. 最簡單直觀的可以用「載客組數／一段時間」或「淨利潤／一段時間」來觀察，透過觀察每天、每周、甚至每月的數值曲線來知曉業績是否有所提升。
#
# ### Q2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# ### A2. 可以透過計程車隊取得，最重要的資料應為載客組數、每趟路程、每趟收入、油錢、額外開銷等會影響之因素，並可將以上因素結合形成不同特徵。
#
# ### Q3. 蒐集而來的資料型態為何
# ### A3. 應為結構化之表格。
#
# ### Q4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# ### A4. 假設找出最重要之特徵數個，則可以透過驗證這些特徵之組合透過迴歸分析來驗證結果。

# %% [markdown]
# # 作業3：

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae
MAE = mean_absolute_error(y, y_hat)

# %%
def mean_squared_error(y, y_hat):
    mse = sum((y - y_hat)**2) / len(y)
    return mse
MSE = mean_squared_error(y, y_hat)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 237.989
# The Mean absolute error is 12.000
